# %% [markdown]
# # feature maps

# %%
layer_names = [layer.name for layer in model.layers]
layer_outputs = [layer.output for layer in model.layers]

feature_map_model = tf.keras.models.Model(input=model.input, output=layer_outputs)

input = img
feature_maps = feature_map_model.predict(input)

for layer_name, feature_map in zip(layer_names, feature_maps):
    print(f"The shape of the {layer_name} is ==> {feature_map.shape}")

# %% [markdown]
# We need to generate feature maps of only convolution layers and not dense layers and hence we will generate feature maps of layers which have “dimension=4".
#
# Each feature map has n-channels and this number “n” is given at the end of the shape of feature map. This is the number of features in a particular layer.
# ES: shape:(1,64,64,8) is an image 64x64 with 8 dimensions, which are the 8 feature (images) combined together to form the final 8dimensional image. So, we need to iterate over this image to separate its 8 images.

# %%
def plot_feature_maps(k,layer_name,image_belt):
    scale = 20. / k
    plt.figure( figsize=(scale * k, scale) )
    plt.title ( layer_name )
    plt.grid  ( False )
    plt.imshow( image_belt, aspect='auto')
    

    for layer_name, feature_map in zip(layer_names, feature_maps):
    if len(feature_map.shape) == 4:
        k = feature_map.shape[-1]  
        size = feature_map.shape[1]
        for i in range(k):
            feature_image = feature_map[0, :, :, i]
            feature_image -= feature_image.mean()
            feature_image /= feature_image.std ()
            feature_image *=  64
            feature_image += 128
            feature_image = np.clip(x, 0, 255).astype('uint8')
            image_belt[:, i * size : (i+1)*size] = feature_image
            
            plot_feature_maps(k,layer_name,image_belt)

# %% [markdown]
# # fix print epoch

# %%
nome="marco"
print(f"ciao {nome}")

i, j, bat_per_epo, d_loss1, d_loss2, g_loss = 0,0,0,1.23332,0,0 
I = i+1 if i>=9 else str("0"+str(i))
print(f"> Epoch {I}: [{j+1}/{bat_per_epo}]\t discriminator_loss1={d_loss1:.3f}  -  discriminator_loss2={d_loss2:.3f}  -  generator_loss={g_loss:.3f}")
# Out:
# ciao marco
# > Epoch 00: [1/0]	 discriminator_loss1=1.233  -  discriminator_loss2=0.000  -  generator_loss=0.000

# %% [markdown]
# # loss plots

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

def plot_losses(points,card):
    
    fig, ax = plt.subplots(figsize=(5, 5))

    points1,points2,points3 = points

    plt.scatter(card,points1)
    plt.scatter(card,points2)
    plt.scatter(card,points3)
    #plt.plot(card,points1,points2,points3)
    plt.plot(card, points1,  'b') # plotting t, a separately 
    plt.plot(card, points2, 'c') # plotting t, a separately 
    plt.plot(card, points3, 'r') # plotting t, a separately 

    ax.set_title('Losses')
    ax.set_xlabel('Epoch')
    ax.set_ylabel('values')
    plt.legend(["d_loss1","d_loss2","g_loss"])

    plt.xticks(np.arange(min(card), max(card)+1, 1))
    #plt.xticks(rotation=90)
    plt.grid()
    plt.show()

# %%
points1 = [random.uniform(1.5, 1.9) for _ in range(10)]
points2 = [random.uniform(1.5, 1.9) for _ in range(10)]
points3 = [random.uniform(1.5, 1.9) for _ in range(10)]
epochs = [i for i in range(1,11)]

plot_losses([points1,points2,points3],epochs)

# %% [markdown]
# # get some paint from artists and find out who is he

# %%
from os import listdir, getcwd
from os.path import join,dirname
import numpy as np
from PIL import Image

dir = join(dirname(dirname(getcwd())),"dataset_art-with-GAN","abstract")
files = listdir(dir)

set  = sorted({int(file.split("_")[0]) for file in files})  #set: no duplicates, it gets all the classes (artists)
list = sorted([int(file.split("_")[0]) for file in files])

n = 23
#for i in range(3):
files[n]    
cardinality = [file2 for file in set for file2 in list if file2==file]

# %%
#WIP

# %% [markdown]
# # artists dictionary

# %%
from os import getcwd
from os.path import join

file = join(getcwd(),"artists.txt")

with open(file,"r+",encoding='utf-8') as f:
    txt = f.readlines()
    txt = [line.split("\n") for line in txt]

ids = [i for i in range(0,len(txt))]
new = [txt[i][0].split(",")[0][:-1] for i in range(len(txt))]

artists_dict = dict(zip(ids,new))
artists_dict[2]
# Out:
# 'Wassily Kandinsky'

# %%
# Out:
# {0: 'Alphonse Allais',
#  1: 'Hilma af Klint',
#  2: 'Wassily Kandinsky',
#  3: 'John Marin',
#  4: 'Piet Mondrian',
#  5: 'Joaquin Torres Garcia',
#  6: 'Bart van der Leck',
#  7: 'Otto Freundlich',
#  8: 'Kazimir Malevich',
#  9: 'Hans Hofmann',
#  10: 'Arthur Dove',
#  11: 'Agnes Lawrence Pelton',
#  12: 'Patrick Henry Bruce',
#  13: 'Theo van Doesburg',
#  14: 'Georgy Yakulov',
#  15: 'Janos Mattis-Teutsch',
#  16: 'Lawren Harris',
#  17: 'Sonia Delaunay',
#  18: 'Morgan Russell',
#  19: 'Jean Arp',
#  20: 'Roger Bissière',
#  21: 'Georges Vantongerloo',
#  22: 'Austin Osman Spare',
#  23: 'Josef Albers',
#  24: 'Alberto Magnelli',
#  25: 'Johannes Itten',
#  26: 'Félix Del Marle',
#  27: 'Anne Ryan',
#  28: 'Willi Baumeister',
#  29: 'Rudolf Bauer',
#  30: 'Peter Laszlo Peri',
#  31: 'Serge Charchoune',
#  32: 'Carl Buchheister',
#  33: 'Mark Tobey',
#  34: 'Erich Buchholz',
#  35: 'Alma Woodsey Thomas',
#  36: 'Camille Graeser',
#  37: 'Adolf Fleischmann',
#  38: 'Leo Leuppi',
#  39: 'Wladyslaw Strzeminski',
#  40: 'Henryk Stazewski',
#  41: 'Ben Nicholson',
#  42: 'Henryk Berlewi',
#  43: 'Marcelle Cahn',
#  44: 'Galliano Mazzon',
#  45: 'Atanasio Soldati',
#  46: 'Robert Strubin',
#  47: 'Jock Macdonald',
#  48: 'Victor Servranckx',
#  49: 'Benedetta Cappa',
#  50: 'Jean Fautrier',
#  51: 'Julius Evola',
#  52: 'John McLaughlin',
#  53: 'Fritz Glarner',
#  54: 'Bradley Walker Tomlin',
#  55: 'Friedrich Vordemberge-Gildewart',
#  56: 'Jack Tworkov',
#  57: 'Adja Yunkers',
#  58: 'Cesar Domela',
#  59: 'Bice Lazzari',
#  60: 'Lolo Soldevilla',
#  61: 'Michel Seuphor',
#  62: 'Ernst Wilhelm Nay',
#  63: 'Boris Margo',
#  64: 'Giuseppe Pinot-Gallizio',
#  65: 'Hans Hinterreiter',
#  66: 'Andre Lanskoy',
#  67: 'Richard Paul Lohse',
#  68: 'José Pedro Costigliolo',
#  69: 'Louis Schanker',
#  70: 'Adolph Gottlieb',
#  71: 'Mark Rothko',
#  72: 'Antonio Calderara',
#  73: 'Alfred Jensen',
#  74: 'Balcomb Greene',
#  75: 'Giorgio Cavallon',
#  76: 'Francis Bott',
#  77: 'Maurice Esteve',
#  78: 'Clyfford Still',
#  79: 'Perle Fine',
#  80: 'John Ferren',
#  81: 'Barnett Newman',
#  82: 'Wolfgang Paalen',
#  83: 'Fritz Winter',
#  84: 'Pierre Tal-Coat',
#  85: 'Leon Polk Smith',
#  86: 'Serge Poliakoff',
#  87: 'Burgoyne Diller',
#  88: 'Camille Bryen',
#  89: 'Ulfert Wilke',
#  90: 'Ilya Bolotowsky',
#  91: 'Giuseppe Santomaso',
#  92: 'Bruno Munari',
#  93: 'Myron Stout',
#  94: 'Rupprecht Geiger',
#  95: 'Luigi Veronesi',
#  96: 'Maria Helena Vieira da Silva',
#  97: 'William Saroyan',
#  98: 'Jorge Oteiza',
#  99: 'Lee Krasner',
#  100: 'Max Bill',
#  101: 'Gustave Singier',
#  102: 'Jack Bush',
#  103: 'Jean Bertholle',
#  104: 'Norman Lewis',
#  105: 'Antonio Corpora',
#  106: 'Jean Le Moal',
#  107: 'Paul Feeley',
#  108: 'Franz Kline',
#  109: 'Hedda Sterne',
#  110: 'Raoul Ubac',
#  111: 'Richard Mortensen',
#  112: 'Aurelie Nemours',
#  113: 'Leon Berkowitz',
#  114: 'Hiroyuki Tajima',
#  115: 'Raul Lozza',
#  116: 'Alfred Manessier',
#  117: 'Olle Baertling',
#  118: 'Lothar Charoux',
#  119: 'Jackson Pollock',
#  120: 'Giulio Turcato',
#  121: 'Afro',
#  122: 'Agnes Martin',
#  123: 'Verena Loewensberg',
#  124: 'Emil Schumacher',
#  125: 'Vasile Dobrian',
#  126: 'Alexander Liberman',
#  127: 'John Cage',
#  128: 'Morris Louis',
#  129: 'Mario Ballocco',
#  130: 'Jean-Michel Atlan',
#  131: 'William Scott',
#  132: 'Carmelo Arden Quin',
#  133: 'Toko Shinoda',
#  134: 'Conrad Marca-Relli',
#  135: 'Philip Guston',
#  136: 'Ad Reinhardt',
#  137: 'Jose Guerrero',
#  138: 'Karl Otto Gotz',
#  139: 'Aurel Cojan',
#  140: 'Peter Busa',
#  141: 'Johannes Jan Schoonhoven',
#  142: 'Nassos Daphnis',
#  143: 'Alexandre Istrati',
#  144: 'Natalia Dumitresco',
#  145: 'Tihamer Gyarmathy',
#  146: 'Robert Motherwell',
#  147: 'Mathias Goeritz',
#  148: 'Friedel Dzubas',
#  149: 'Carmen Herrera',
#  150: 'Bernard Schultze',
#  151: 'Gunther Gerzso',
#  152: 'Terry Frost',
#  153: 'Richard Pousette-Dart',
#  154: 'Fernand Leduc',
#  155: 'Pablo Palazuelo',
#  156: 'Lennart Rodhe',
#  157: 'Gottfried Honegger',
#  158: 'Marcelle Loubchansky',
#  159: 'Mario Nigro',
#  160: 'Edna Andrade',
#  161: 'Nicolas Carone',
#  162: 'Jean Degottex',
#  163: 'Rune Jansson',
#  164: 'Paul Reed',
#  165: 'Frederick Hammersley',
#  166: 'Rene Duvillier',
#  167: 'Mira Schendel',
#  168: 'Edward Corbett',
#  169: 'Taro Yamamoto',
#  170: 'Pierre Soulages',
#  171: 'Huguette Arthur Bertrand',
#  172: 'Zao Wou-Ki',
#  173: 'George Saru',
#  174: 'Amilcar de Castro',
#  175: 'Jimmy Ernst',
#  176: 'Jean Messagier',
#  177: 'Gene Davis',
#  178: 'Chu Teh-Chun',
#  179: 'Nadir Afonso',
#  180: 'Frank Lobdell',
#  181: 'Lidy Prati',
#  182: 'Georges Mathieu',
#  183: 'Anne Truitt',
#  184: 'Norman Bluhm',
#  185: 'Bram Bogart',
#  186: 'Ray Parker',
#  187: 'Tomas Maldonado',
#  188: 'William Turnbull',
#  189: 'S. H. Raza',
#  190: 'Emilio Scanavino',
#  191: 'Pedro Coronel',
#  192: 'Jules Olitski',
#  193: 'Jaroslav Serpan',
#  194: 'Ramirez Villamizar',
#  195: 'Sadamasa Motonaga',
#  196: 'Simon Hantai',
#  197: 'Jacques Busse',
#  198: 'Theodoros Stamos',
#  199: 'Ivan Serpa',
#  200: 'Gunter Fruhtrunk',
#  201: 'Jerzy Nowosielski',
#  202: 'Genevieve Asse',
#  203: 'Ellsworth Kelly',
#  204: 'Sam Francis',
#  205: 'Paul Jenkins',
#  206: 'Luigi Guardigli',
#  207: 'Mario Cesariny',
#  208: 'Fernando Lanhas',
#  209: 'Jean-Paul Riopelle',
#  210: 'Antonio Sanfilippo',
#  211: 'Antoni Tapies',
#  212: 'Olga Albizu',
#  213: 'Kazuo Shiraga',
#  214: 'Luis Sacilotto',
#  215: 'Akira Kanayama',
#  216: 'Paul Brach',
#  217: 'Herbert Zangs',
#  218: 'Behjat Sadr',
#  219: 'Manabu Mabe',
#  220: 'Martin Barre',
#  221: 'Francois Arnal',
#  222: 'Oskar Holweck',
#  223: 'Richards Ruben',
#  224: 'Joan Mitchell',
#  225: 'Marcel Barbeau',
#  226: 'Etel Adnan',
#  227: 'Edward Krasinski',
#  228: 'Almir Mavignier',
#  229: 'Modest Cuixart',
#  230: 'John Altoon',
#  231: 'Karl Benjamin',
#  232: 'Stanley Boxer',
#  233: 'Jean Miotte',
#  234: 'Francois Morellet',
#  235: 'Hannelore Baron',
#  236: 'Moshe Kupferman',
#  237: 'Stefan Sevastre',
#  238: 'Adnan Coker',
#  239: 'Tony DeLap',
#  240: 'Warren Rohrer',
#  241: 'James Bishop',
#  242: 'Manuel Rivera',
#  243: 'Ludwig Wilding',
#  244: 'Piero Dorazio',
#  245: 'Pierre Alechinsky',
#  246: 'Thomas Downing',
#  247: 'Al Held',
#  248: 'Yun Hyong–keun',
#  249: 'Omar Rayo',
#  250: 'Jean-Paul Jerome',
#  251: 'Theo Gerber',
#  252: 'Cy Twombly',
#  253: 'Jagdish Swaminathan',
#  254: 'JCJ Vanderheyden',
#  255: 'Ward Jackson',
#  256: 'Helen Frankenthaler',
#  257: 'Manuel Felguérez',
#  258: 'Li Yuan-chia',
#  259: 'Horacio Garcia-Rossi',
#  260: 'Jay DeFeo',
#  261: 'Marcia Hafif',
#  262: 'Peter Joseph',
#  263: 'Se-Ok Suh',
#  264: 'Constantin Blendea',
#  265: 'Claude Georges',
#  266: 'Nicholas Krushenick',
#  267: 'Turi Simeti',
#  268: 'Ion Alin Gheorghiu',
#  269: 'Luis Feito',
#  270: 'Rodolfo Arico',
#  271: 'Ron Gorchov',
#  272: 'Yuri Zlotnikov',
#  273: 'Richard Anuszkiewicz',
#  274: 'Robert Ryman',
#  275: 'Gotthard Graubner',
#  276: 'Frederic Matys Thursz',
#  277: 'Enrico Castellani',
#  278: 'Raoul De Keyser',
#  279: 'Dadamaino',
#  280: 'Charlotte Posenenske',
#  281: 'Howard Mehring',
#  282: 'Park Seo-Bo',
#  283: 'Cesar Paternosto',
#  284: 'Joan Hernandez Pijuan',
#  285: 'Richard Smith',
#  286: 'Norman Zammitt',
#  287: 'Heinz Mack',
#  288: 'Bridget Riley',
#  289: 'Antonio Asis',
#  290: 'Rubem Ludolf',
#  291: 'Dorothea Rockburne',
#  292: 'Gebre Kristos Desta',
#  293: 'Gerhard Richter',
#  294: 'Helmut Sturm',
#  295: 'Ion Nicodim',
#  296: 'Jef Verheyen',
#  297: 'Romul Nutiu',
#  298: 'Howard Hodgkin',
#  299: 'Marc Vaux',
#  300: 'Claude Tousignant',
#  301: 'Walter Leblanc',
#  302: 'Bernard Cohen',
#  303: 'Kazuaki Tanahashi',
#  304: 'Fernando García Ponce',
#  305: 'Kuno Gonschior',
#  306: 'Guido Molinari',
#  307: 'Sam Gilliam',
#  308: 'Victor Bonato',
#  309: 'Charles Bezie',
#  310: 'Bernard Aubertin',
#  311: 'Yves Gaucher',
#  312: 'Bob Law',
#  313: 'Jeremy Moon',
#  314: 'Gerhard von Graevenitz',
#  315: 'Walter Darby Bannard',
#  316: 'John Hoyland',
#  317: 'Tadasky',
#  318: 'Robert Huot',
#  319: 'Roman Cotosman',
#  320: 'Guy Mees',
#  321: 'Ha Chong-Hyun',
#  322: 'Agostino Bonalumi',
#  323: 'Jerry W. McDaniel',
#  324: 'Claude Viallat',
#  325: 'Constantin Flondor',
#  326: 'Lee Ufan',
#  327: 'Leo Valledor',
#  328: 'Giorgio Griffa',
#  329: 'Joachim Bandau',
#  330: 'Frank Stella',
#  331: 'Edward Avedisian',
#  332: 'Rochelle Blumenfeld',
#  333: 'Doug Ohlson',
#  334: 'Monique Orsini',
#  335: 'Ronald Davis',
#  336: 'Joe Goode',
#  337: 'Matsutani',
#  338: 'Nasreen Mohamedi',
#  339: 'Niele Toroni',
#  340: 'Larry Zox',
#  341: 'Grazia Varisco',
#  342: 'Robert Mangold',
#  343: 'Tess Jaray',
#  344: 'Pino Pinelli',
#  345: 'Michel Parmentier',
#  346: 'Pat Steir',
#  347: 'Angelo de Sousa',
#  348: 'Daniel Buren',
#  349: 'Mark Lancaster',
#  350: 'Eduardo Nery',
#  351: 'Brice Marden',
#  352: 'Jan Groth',
#  353: 'Akkitham Narayanan',
#  354: 'Andre-Pierre Arnal',
#  355: 'Rafa Nasiri',
#  356: 'Imi Knoebel',
#  357: 'Paolo Scheggi',
#  358: 'Ettore Spalletti',
#  359: 'Phil Sims',
#  360: 'Robert Swain',
#  361: 'Pat Lipsky',
#  362: 'Claude Rutault',
#  363: 'Richard Tuttle',
#  364: 'Silviu Oravitzan',
#  365: 'Daan Lemaire',
#  366: 'Gunter Umberg',
#  367: 'Blinky Palermo',
#  368: 'Joseph Marioni',
#  369: 'Florin Maxa',
#  370: 'Francois Rouan',
#  371: 'Olivier Mosset',
#  372: 'Soledad Sevilla',
#  373: 'Helmut Federle',
#  374: 'Louis Cane',
#  375: 'Mary Corse',
#  376: 'Ion Pantilie',
#  377: 'Sean Scully',
#  378: 'Antonio Palolo',
#  379: 'Stanley Whitney',
#  380: 'Jean-Francois Dubreuil',
#  381: 'Gary Wragg',
#  382: 'Harriet Korman',
#  383: 'Ronnie Landfield',
#  384: 'Tiberiy Szilvashi',
#  385: 'Stephen Mueller',
#  386: 'Requena Nozal',
#  387: 'Alan Charlton',
#  388: 'Gregg Renfrow',
#  389: 'Rudolf de Crignis',
#  390: 'Luciano Bartolini',
#  391: 'Roger Weik',
#  392: 'Georges Troubat',
#  393: 'Gerwald Rockenschaub',
#  394: 'Peter Halley',
#  395: 'Andrzej Nowacki',
#  396: 'Gunther Forg',
#  397: 'Anne Appleby',
#  398: 'Jill Baroff',
#  399: 'Bruno Jakob',
#  400: 'Michael Krebber',
#  401: 'Philip Taaffe',
#  402: 'Gaylen Gerber',
#  403: 'Pedro Cabrita Reis',
#  404: 'Charles Gibbons',
#  405: 'Barbara McGivern',
#  406: 'Heimo Zobernig',
#  407: 'Moon Pil Shim',
#  408: 'Christian Eckart',
#  409: 'Iseult Labote',
#  410: 'Mostafa Dashti',
#  411: 'Eric Zammitt',
#  412: 'Sofia Areal',
#  413: 'Gennady Mironov',
#  414: 'Ding Yi',
#  415: 'Callum Innes',
#  416: 'Gianni Sarcone',
#  417: 'Josignacio',
#  418: 'Jan Maarten Voskuil',
#  419: 'Carsten Nicolai',
#  420: 'Darren Waterston',
#  421: 'Mariojosé Ángeles',
#  422: 'Ian Davenport',
#  423: 'Daniel Sambo-Richter',
#  424: 'Bernd Luz',
#  425: 'Sarah Morris',
#  426: "Ilse D'Hollander",
#  427: 'Pablo Rey',
#  428: 'Wolfgang Tillmans',
#  429: 'Paula Klien',
#  430: 'Julie Mehretu',
#  431: 'Lorenzo Belenguer',
#  432: 'Xu Hongming',
#  433: 'Albrecht Behmel',
#  434: 'Thomas Riesner',
#  435: 'Cameron Platter',
#  436: 'Justin Earl Grant',
#  437: 'Rodrigo Franzao',
#  438: 'Jacob Kassay',
#  439: 'Yui Yaegashi',
#  440: 'Nemanja Vuckovic',
#  441: 'Sharon Butler'}
